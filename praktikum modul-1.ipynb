# %%
print("hello world")
print("saya sedang belajar python")
# Out:
# hello world
# saya sedang belajar python

# %%
print("hello word");print("saya sedang belajar python")
# Out:
# hello word
# saya sedang belajar python

# %%
print("hello world")

a = 1
b = 2
print(b)
# Out:
# hello world
# 2

# %%
if (5 > 2):
    print("5 lebih besar dari 2")
    
print("ini bukan baris if")
# Out:
# 5 lebih besar dari 2
# ini bukan baris if

# %%
x = 10
y = "belajar python"

print(x)
print(y)
# Out:
# 10
# belajar python

# %%
x, y, z = "Santi", "Citra", "Rozy"
print(x, y, z)
print(y)
print(z)
# Out:
# Santi Citra Rozy
# Citra
# Rozy

# %%
x = "awesome"

def myfunc():
    y = "fantastic"
    print(f"Python is {x} and {y}")

def myfunc2():
    y = "oke"
    print(f"Python is {x} and {y}")
    
myfunc()
myfunc2()
# Out:
# Python is awesome and fantastic
# Python is awesome and oke

# %%
x ="awesome"

def myfunc():
    global x
    x = "awesome_"
    y = "fantastic"
    print(f"Python is {x}and {y}")
    
def myfunc2():
    y = "oke"
    print(f"Python is {x}and {y}")
    
myfunc()
myfunc2()
# Out:
# Python is awesome_and fantastic
# Python is awesome_and oke
