# %%
#program 4.1

list1 = ["apel", "nanas", 1 , False]
print('list index ke 0 :', list1[0])

list1[2] = "sepeda"
print(list1)

list1.append("cangkul")
print(list1)

list1.remove(False)
print(list1)
# Out:
# list index ke 0 : apel
# ['apel', 'nanas', 'sepeda', False]
# ['apel', 'nanas', 'sepeda', False, 'cangkul']
# ['apel', 'nanas', 'sepeda', 'cangkul']

# %%
#program 4.2

tup1 = (11, 12.13, 14+15j)
tup2 = ("nanas", "mangga")

tup3 = tup1 + tup2
print(tup3)

tup4 = tuple(['pisang', 'pepaya'])
print(tup4)
# Out:
# (11, 12.13, (14+15j), 'nanas', 'mangga')
# ('pisang', 'pepaya')

# %%
#program 4.3

set1 = {"apel", "jeruk", "pisang"}

set1.add("mangga")
print(set1)

set1.remove("jeruk")
print(set1)

print("apel" in set1)

set2 = {"mangga", "nanas"}
print(set2.union(set1))
# Out:
# {'apel', 'jeruk', 'pisang', 'mangga'}
# {'apel', 'pisang', 'mangga'}
# True
# {'pisang', 'apel', 'mangga', 'nanas'}

# %%
#program 4.4

dict1 = {"merk": "ford", "model": "mustang", "tahun": 1964}
print(dict1)

dict1.update({"tahun": 2020})
print(dict1)

dict1["warna"] = "merah"
print(dict1)

dict1.pop("tahun")
print(dict1)
# Out:
# {'merk': 'ford', 'model': 'mustang', 'tahun': 1964}
# {'merk': 'ford', 'model': 'mustang', 'tahun': 2020}
# {'merk': 'ford', 'model': 'mustang', 'tahun': 2020, 'warna': 'merah'}
# {'merk': 'ford', 'model': 'mustang', 'warna': 'merah'}

# %%
#program 4.5

a = 1

if (a < 2):
    print("a lebih kecil dari 2")
# Out:
# a lebih kecil dari 2

# %%
#Program 4.6

a = 3

if (a < 2):
    print(a, "lebih kecil dari 2")
else:
    print(a, "lebih besar dari 2")
# Out:
# 3 lebih besar dari 2

# %%
#program 4.7

a = int(input("Masukkan nilai a :"))
b = int(input("Masukkan nilai b :"))
print(a, "dan", b)
if b > a:
    print(b, "lebih besar dari", a)
elif a == b:
    print(a,"sama dengan", b)
else:
    print(a,"lebih besar dari", b)
# Out:
# 10 dan 5
# 10 lebih besar dari 5
